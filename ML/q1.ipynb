# %% [markdown]
# ## Lukemia Remission

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy

# %%
data_set = pd.read_csv('./q1.csv', header=0)

# %%
data_set.head(3)
# Out:
#    REMISS  CELL  SMEAR  INFIL   LI  BLAST  TEMP
# 0       1   0.8   0.83   0.66  1.9   1.10  1.00
# 1       1   0.9   0.36   0.32  1.4   0.74  0.99
# 2       0   0.8   0.88   0.70  0.8   0.18  0.98

# %%
feature_cols = ['CELL','SMEAR','INFIL','LI','BLAST','TEMP']
X = data_set[feature_cols]
Y = data_set['REMISS']

# %%
X
# Out:
#     CELL  SMEAR  INFIL   LI  BLAST  TEMP
# 0   0.80   0.83   0.66  1.9   1.10  1.00
# 1   0.90   0.36   0.32  1.4   0.74  0.99
# 2   0.80   0.88   0.70  0.8   0.18  0.98
# 3   1.00   0.87   0.87  0.7   1.05  0.99
# 4   0.90   0.75   0.68  1.3   0.52  0.98
# 5   1.00   0.65   0.65  0.6   0.52  0.98
# 6   0.95   0.97   0.92  1.0   1.23  0.99
# 7   0.95   0.87   0.83  1.9   1.35  1.02
# 8   1.00   0.45   0.45  0.8   0.32  1.00
# 9   0.95   0.36   0.34  0.5   0.00  1.04
# 10  0.85   0.39   0.33  0.7   0.28  0.99
# 11  0.70   0.76   0.53  1.2   0.15  0.98
# 12  0.80   0.46   0.37  0.4   0.38  1.01
# 13  0.20   0.39   0.08  0.8   0.11  0.99
# 14  1.00   0.90   0.90  1.1   1.04  0.99
# 15  1.00   0.84   0.84  1.9   2.06  1.02
# 16  0.65   0.42   0.27  0.5   0.11  1.01
# 17  1.00   0.75   0.75  1.0   1.32  1.00
# 18  0.50   0.44   0.22  0.6   0.11  0.99
# 19  1.00   0.63   0.63  1.1   1.07  0.99
# 20  1.00   0.33   0.33  0.4   0.18  1.01
# 21  0.90   0.93   0.84  0.6   1.59  1.02
# ...

# %%
X.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000261B814DA30>,
# ...
#       dtype=object)

# %%
X.describe()
# Out:
#             CELL      SMEAR      INFIL         LI      BLAST       TEMP
# count  27.000000  27.000000  27.000000  27.000000  27.000000  27.000000
# mean    0.881481   0.635185   0.570741   1.003704   0.688519   0.997407
# std     0.186645   0.214052   0.237567   0.467795   0.534960   0.014830
# min     0.200000   0.320000   0.080000   0.400000   0.000000   0.980000
# 25%     0.825000   0.430000   0.335000   0.650000   0.230000   0.990000
# 50%     0.950000   0.650000   0.630000   0.900000   0.520000   0.990000
# 75%     1.000000   0.835000   0.740000   1.250000   1.060000   1.005000
# max     1.000000   0.970000   0.920000   1.900000   2.060000   1.040000

# %%
Y.hist()

# %%
d_data = data_set.select_dtypes(exclude=['object'])
sns.pairplot(data_set, diag_kind = 'hist')
