# %% [markdown]
# ## Lukemia Remission

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy

# %%
train_data = pd.read_csv('./q1.csv', header=0)

# %%
train_data
# Out:
#     REMISS  CELL  SMEAR  INFIL    LI  BLAST  TEMP
# 0        1   0.8    0.7   0.66  1.90    1.1     1
# 1        1   1.0    0.7   0.66  1.90    1.1     1
# 2        1   0.8    0.7   0.66  1.90    1.1     1
# 3        1   0.8    0.7   0.66  1.90    1.1     1
# 4        1   0.8    0.7   0.66  1.90    1.1     1
# 5        1   0.8    0.7   0.66  1.90    1.1     1
# 6        1   0.8    0.7   0.66  1.90    1.1     1
# 7        1   0.8    0.7   0.66  1.90    1.1     1
# 8        1   0.8    0.7   0.66  1.90    1.1     1
# 9        1   0.3   95.0   0.66  1.90    1.1     1
# 10       1   0.8    0.7   0.66  1.90    1.1     1
# 11       1   0.8    0.7   0.66  1.90    1.1     1
# 12       1   0.6    0.7   0.66  1.90    1.1     1
# 13       1   0.8    0.7   0.70  1.90    1.1     0
# 14       1   0.8    0.7   0.66  1.90    1.1     1
# 15       1   0.8    0.7   0.66  1.90    1.1     1
# 16       1   0.8    0.7   0.66  1.90    1.3     1
# 17       1   0.8    0.7   0.66  1.04    1.1     1
# ...
